# %%
import pandas as pd

data = pd.read_csv("../data/demanda_comercial.csv.zip", compression="zip")
data.head() # Los valores de las columnas H## son la demanda por hora
# Out:
#         Fecha         H01         H02         H03         H04         H05  \
# 0  2017-01-01  6090271.96  5887031.28  5708693.89  5538133.02  5389774.53
# 1  2017-01-02  5557603.42  5361012.17  5239119.86  5163721.70  5249539.75
# 2  2017-01-03  6160676.02  5924880.04  5764416.93  5685832.28  5778222.13
# 3  2017-01-04  6321851.20  6092135.24  5905390.85  5827867.82  5925730.02
# 4  2017-01-05  6395397.96  6162409.22  6001153.67  5918673.26  6005924.21
#
#           H06         H07         H08         H09  ...         H15  \
# 0  5288199.94  4851217.85  4876162.18  5073813.27  ...  5745568.87
# 1  5438852.95  5566947.57  6055220.80  6588005.66  ...  7610559.73
# 2  5985840.29  6083907.36  6545100.21  7092804.54  ...  8148614.93
# 3  6182279.89  6276759.96  6737660.53  7256819.19  ...  8164513.51
# 4  6225027.53  6322923.78  6739120.44  7307847.42  ...  8144209.65
#
#           H16         H17         H18         H19         H20         H21  \
# ...

# %%
# Se organizan los datos para graficarlos.

data_to_plot = data.copy()
data_to_plot = data_to_plot.melt(
    id_vars=["Fecha"], var_name="hora", value_name="demanda"
)
data_to_plot = data_to_plot.sort_values(by=["Fecha", "hora"])
data_to_plot = data_to_plot.reset_index(drop=True)
data_to_plot = data_to_plot.head(2000)
data_to_plot.head(30)
# Out:
#          Fecha hora     demanda
# 0   2017-01-01  H01  6090271.96
# 1   2017-01-01  H02  5887031.28
# 2   2017-01-01  H03  5708693.89
# 3   2017-01-01  H04  5538133.02
# 4   2017-01-01  H05  5389774.53
# 5   2017-01-01  H06  5288199.94
# 6   2017-01-01  H07  4851217.85
# 7   2017-01-01  H08  4876162.18
# 8   2017-01-01  H09  5073813.27
# 9   2017-01-01  H10  5359713.29
# 10  2017-01-01  H11  5586470.17
# 11  2017-01-01  H12  5770471.79
# 12  2017-01-01  H13  5847839.73
# 13  2017-01-01  H14  5844160.87
# 14  2017-01-01  H15  5745568.87
# 15  2017-01-01  H16  5647807.40
# 16  2017-01-01  H17  5609297.84
# 17  2017-01-01  H18  5690105.56
# 18  2017-01-01  H19  6761038.26
# 19  2017-01-01  H20  7077861.59
# 20  2017-01-01  H21  6979468.90
# 21  2017-01-01  H22  6695312.12
# 22  2017-01-01  H23  6289107.72
# 23  2017-01-01  H24  5794545.98
# 24  2017-01-02  H01  5557603.42
# 25  2017-01-02  H02  5361012.17
# 26  2017-01-02  H03  5239119.86
# 27  2017-01-02  H04  5163721.70
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(data_to_plot["demanda"])
plt.title("Demanda comercial")
plt.xlabel("Tiempo")
plt.ylabel("Demanda")
plt.grid()
plt.savefig("../submission/demanda-comercial.png")
plt.show()

# %%
data.head()
# Out:
#         Fecha         H01         H02         H03         H04         H05  \
# 0  2017-01-01  6090271.96  5887031.28  5708693.89  5538133.02  5389774.53
# 1  2017-01-02  5557603.42  5361012.17  5239119.86  5163721.70  5249539.75
# 2  2017-01-03  6160676.02  5924880.04  5764416.93  5685832.28  5778222.13
# 3  2017-01-04  6321851.20  6092135.24  5905390.85  5827867.82  5925730.02
# 4  2017-01-05  6395397.96  6162409.22  6001153.67  5918673.26  6005924.21
#
#           H06         H07         H08         H09  ...         H15  \
# 0  5288199.94  4851217.85  4876162.18  5073813.27  ...  5745568.87
# 1  5438852.95  5566947.57  6055220.80  6588005.66  ...  7610559.73
# 2  5985840.29  6083907.36  6545100.21  7092804.54  ...  8148614.93
# 3  6182279.89  6276759.96  6737660.53  7256819.19  ...  8164513.51
# 4  6225027.53  6322923.78  6739120.44  7307847.42  ...  8144209.65
#
#           H16         H17         H18         H19         H20         H21  \
# ...

# %%
# Preparación de la data

data = data.dropna()
data = data.drop_duplicates()
data = data.set_index("Fecha") # Se establece la columna "Fecha" como índice 

data.head()
# Out:
#                    H01         H02         H03         H04         H05  \
# Fecha
# 2017-01-01  6090271.96  5887031.28  5708693.89  5538133.02  5389774.53
# 2017-01-02  5557603.42  5361012.17  5239119.86  5163721.70  5249539.75
# 2017-01-03  6160676.02  5924880.04  5764416.93  5685832.28  5778222.13
# 2017-01-04  6321851.20  6092135.24  5905390.85  5827867.82  5925730.02
# 2017-01-05  6395397.96  6162409.22  6001153.67  5918673.26  6005924.21
#
#                    H06         H07         H08         H09         H10  ...  \
# Fecha                                                                   ...
# 2017-01-01  5288199.94  4851217.85  4876162.18  5073813.27  5359713.29  ...
# 2017-01-02  5438852.95  5566947.57  6055220.80  6588005.66  6979088.72  ...
# 2017-01-03  5985840.29  6083907.36  6545100.21  7092804.54  7461185.94  ...
# 2017-01-04  6182279.89  6276759.96  6737660.53  7256819.19  7608691.40  ...
# 2017-01-05  6225027.53  6322923.78  6739120.44  7307847.42  7619827.03  ...
# ...

# %%
# Patrones de ejemplo

plt.figure(figsize=(7, 4))
plt.plot(data.loc["2017-06-05", :], ".-", color="tab:blue")
plt.plot(data.loc["2018-06-05", :], ".-", color="tab:orange")
plt.plot(data.loc["2022-06-03", :], ".-", color="tab:green")
plt.xticks(rotation=90)
plt.show()

# %%
# Se divide cada fila por el máximo de la fila para
# hacer adimensionales los datos

data = data.apply(lambda row: row / row.max(), axis=1) # Normalización de los datos por fila
data.head(10)
# Out:
#                  H01       H02       H03       H04       H05       H06  \
# Fecha
# 2017-01-01  0.860468  0.831753  0.806556  0.782459  0.761498  0.747147
# 2017-01-02  0.655213  0.632036  0.617666  0.608777  0.618894  0.641213
# 2017-01-03  0.697234  0.670548  0.652387  0.643493  0.653950  0.677447
# 2017-01-04  0.713507  0.687580  0.666503  0.657754  0.668799  0.697754
# 2017-01-05  0.724097  0.697718  0.679460  0.670122  0.680001  0.704808
# 2017-01-06  0.721367  0.693060  0.677716  0.669919  0.680114  0.711488
# 2017-01-07  0.771179  0.737493  0.719772  0.707964  0.712711  0.727125
# 2017-01-08  0.815849  0.785902  0.760155  0.743666  0.738028  0.739256
# 2017-01-09  0.741549  0.717449  0.697649  0.688828  0.693286  0.697630
# 2017-01-10  0.667308  0.639970  0.628090  0.626889  0.646465  0.683864
#
#                  H07       H08       H09       H10  ...       H15       H16  \
# Fecha                                               ...
# ...

# %%
# Patrones de ejemplo

plt.figure(figsize=(7, 4))
plt.plot(data.loc["2017-06-05", :], ".-", color="tab:blue")
plt.plot(data.loc["2018-06-05", :], ".-", color="tab:orange")
plt.plot(data.loc["2022-06-06", :], ".-", color="tab:green")
plt.xticks(rotation=90)
plt.savefig("../submission/demanda-comercial-patrones-ejemplo.png")
plt.show()

# %%
# Determinación de la cantidad de perfiles diferentes

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

n_clusters = 10
scores = []

for n in range(2, n_clusters): # Se prueba con diferentes cantidades de clusters

    kmeans = KMeans(n_clusters=n, n_init="auto")
    kmeans.fit(data) # Entrenamiento para encontrar cuantos clusters hay en los datos
    labels = kmeans.labels_
    scores.append(silhouette_score(data, labels, metric="euclidean")) # Se calcula el score de silueta para cada cantidad de clusters


plt.figure(figsize=(5, 4))
plt.plot(range(2, n_clusters), scores, marker="o", color="tab:blue", alpha=0.9)
plt.xlabel("número de clusters")
plt.gca().spines["left"].set_color("gray")
plt.gca().spines["bottom"].set_color("gray")
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.grid()
plt.show()

# %%
# Dos patrones óptimos

kmeans = KMeans(n_clusters=2, n_init="auto")
kmeans.fit(data)

plt.figure(figsize=(7, 4))
plt.plot(kmeans.cluster_centers_[0], ".-", color="tab:blue") # 
plt.plot(kmeans.cluster_centers_[1], ".-", color="tab:orange")
plt.savefig("../submission/demanda-comercial-perfiles.png")
plt.show()

# %%
# Adiciona el numero del cluster correspondiente a cada fila
# y agrega el día de la semana (como entero). El domingo
# es el día 0.

data = data.assign(cluster=kmeans.labels_)
data = data.assign(day=pd.to_datetime(data.index).day_of_week)
data[["cluster", "day"]]
# Out:
#             cluster  day
# Fecha
# 2017-01-01        1    6
# 2017-01-02        1    0
# 2017-01-03        0    1
# 2017-01-04        0    2
# 2017-01-05        0    3
# ...             ...  ...
# 2022-08-27        0    5
# 2022-08-28        1    6
# 2022-08-29        0    0
# 2022-08-30        0    1
# 2022-08-31        0    2
#
# [2069 rows x 2 columns]

# %%
# por cluster para el cluster 0

data_per_cluster_0 = data.loc[data.cluster == 0, "day"]
days_cluster_0 = data_per_cluster_0.value_counts()
days_cluster_0 = days_cluster_0.sort_index()
days_cluster_0
# Out:
# day
# 0    229
# 1    283
# 2    284
# 3    284
# 4    278
# 5    267
# Name: count, dtype: int64

# %%
# numero de dias por cluster para el cluster 1

data_per_cluster_1 = data.loc[data.cluster == 1, "day"]
days_cluster_1 = data_per_cluster_1.value_counts()
days_cluster_1 = days_cluster_1.sort_index()
days_cluster_1
# Out:
# day
# 0     67
# 1     13
# 2     12
# 3     11
# 4     17
# 5     28
# 6    296
# Name: count, dtype: int64

# %%
#almacena los resultados en un archivo CSV

pd.DataFrame(
    {
        'days': list(range(7)),
        'cluster 0':days_cluster_0,
        'cluster 1':days_cluster_1,
    }
).to_csv('../submission/demanda-comercial-dias.csv')
